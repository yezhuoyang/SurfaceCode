# %%
from surface import *

# %%
suf=surfaceCode(3)

# %%
suf.draw_surface()
# Out:
# Q1----Q2----Q3
# |     |     |
# |     |     |
# Q4----Q5----Q6
# |     |     |
# |     |     |
# Q7----Q8----Q9

# %%
suf.print_stab()
# Out:
# X1-X2-X4-X5
# X4-X5-X7-X8
# X2-X3
# X8-X9
# Z2-Z3-Z5-Z6
# Z5-Z6-Z8-Z9
# Z1-Z4
# Z3-Z6

# %%
suf.inject_error({1:'X',3:'Z',8:'X'})
suf.compile_syndrome_circuit()

# %%
circuit=suf.get_circuit()

# %%
circuit.draw('mpl')
